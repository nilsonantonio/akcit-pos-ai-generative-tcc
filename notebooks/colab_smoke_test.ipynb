# %% [markdown]
# # Colab Smoke Test\nNotebook para validar ambiente, dependencias e contrato dos artefatos.

# %%
# !nvidia-smi || true\n!python --version

# %%
# !pip install -r requirements-linux-gpu.txt

# %%
# !python -B -c "from tests.smoke_test import *; test_prompt_file_has_expected_contract(); test_run_matrix_generation(); test_speaker_selection_from_curated_metadata(); test_metric_aggregation_contract(); test_wer_computation(); print('smoke tests passed')"
