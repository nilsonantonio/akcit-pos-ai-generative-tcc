# %% [markdown]
# # Colab SpeechT5 Pilot\nNotebook para piloto de 1 speaker com `SpeechT5 zero-shot`, `few-shot` e `LoRA`.

# %%
from google.colab import drive\ndrive.mount('/content/drive')

# %%
# !pip install -r requirements-linux-gpu.txt

# %%
# !python scripts/generate_run_matrix.py --config configs/speecht5_minimal.yaml --out artifacts/run_matrix.csv\n!python scripts/init_samples.py --run-matrix artifacts/run_matrix.csv --speaker-selection data/manifests/speaker_selection.csv --speaker-embeddings artifacts/embeddings/speaker_embeddings.csv --out artifacts/evaluation/samples.csv
